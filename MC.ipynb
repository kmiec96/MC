# %%
import numpy as np
from scipy.stats import norm, expon, chi2, uniform
import matplotlib.pyplot as plt
import pandas as pd
import random 

# %matplotlib inline
print("DONE")
# Out:
# DONE

# %% [markdown]
# # Standard distributions sampling
# ## Ex 1.
# Use scipy to take samples from the following distributions:
# 1. Normal distribution with $\mu$=1 and $\sigma$=4,
# 2. Exponential distribution with $\lambda = \dfrac{1}{4}$,
# 3. Chi-squared distribution with 8 degrees of freedom,
# 4. Uniform distribution with borders [$-2\sqrt{3}, 6\sqrt{3}$].
#
# Compare their theoretical and sample distribution, mean and variance.

# %%
#1. Normal
#This one I'll do for you :-)
def norm_func(size):
    rv_norm = norm(loc = 1, scale = 4)
    x = np.linspace(rv_norm.ppf(0.01), rv_norm.ppf(0.99), 100)
    fig, ax = plt.subplots(1, 1)
    ax.plot(x, rv_norm.pdf(x), 'r-', lw=5, alpha=0.6, label='norm pdf')
    r = rv_norm.rvs(size)
    ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])


    ax.legend(loc='best', frameon=False)
    plt.show()

    print("Distribution mean: {0}".format(rv_norm.stats(moments='m')))
    print("Distribution variance: {0}".format(rv_norm.stats(moments='v')))
    print("Sample mean: {0}".format(np.mean(r)))
    print("Sample variance: {0}".format(np.var(r)))
norm_func(1000)
# Out:
# Distribution mean: 1.0
# Distribution variance: 16.0
# Sample mean: 1.1453941211524574
# Sample variance: 16.21091371567225

# %%
def exp_func(size):
    rv_exp = expon(loc = 0, scale = 4)
    x = np.linspace(rv_exp.ppf(0.01), rv_exp.ppf(0.99), 100)
    fig, ax = plt.subplots(1, 1)
    ax.plot(x, rv_exp.pdf(x), 'r-', lw=5, alpha=0.6, label='exp pdf')
    r = rv_exp.rvs(size)
    ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])
    
    ax.legend(loc='best', frameon=False)
    plt.show()

    print("Distribution mean: {0}".format(rv_exp.stats(moments='m')))
    print("Distribution variance: {0}".format(rv_exp.stats(moments='v')))
    print("Sample mean: {0}".format(np.mean(r)))
    print("Sample variance: {0}".format(np.var(r)))

exp_func(1000)
# Out:
# Distribution mean: 4.0
# Distribution variance: 16.0
# Sample mean: 3.807243526358164
# Sample variance: 15.515417209737155

# %%
#Widać, że mój wykres powyżej jest taki sam jak ten z polecenia dla (lambda=1/4 mu=0) scale=4 loc=0
# Out:
# Distribution mean: 4.0
# Distribution variance: 16.0
# Sample mean: 4.037945131255746
# Sample variance: 16.703208501810366

# %%
#chi2
#here goes your code
def chi2_func(size):
    rv_chi2 = chi2(df=8, loc=0, scale=1)
    x = np.linspace(rv_chi2.ppf(0.01), rv_chi2.ppf(0.99), 100)
    fig, ax = plt.subplots(1, 1)
    ax.plot(x, rv_chi2.pdf(x), 'r-', lw=5, alpha=0.6, label='chi2 pdf')
    r = rv_chi2.rvs(size)
    ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])


    ax.legend(loc='best', frameon=False)
    plt.show()

    print("Distribution mean: {0}".format(rv_chi2.stats(moments='m')))
    print("Distribution variance: {0}".format(rv_chi2.stats(moments='v')))
    print("Sample mean: {0}".format(np.mean(r)))
    print("Sample variance: {0}".format(np.var(r)))
chi2_func(1000)
# Out:
# Distribution mean: 8.0
# Distribution variance: 16.0
# Sample mean: 7.992017750622608
# Sample variance: 15.987473623818211

# %%
#Widać, że otrzymany przezemnie wykres powyżej dla df=8 jest jednakowy jak ten z polecenia.
# Out:
# Distribution mean: 8.0
# Distribution variance: 16.0
# Sample mean: 8.055888693002915
# Sample variance: 16.486374623715673

# %%
#uniform
#here goes your code
def uniform_func(size):
    rv_uniform = uniform(loc=-2*np.sqrt(3), scale=8*np.sqrt(3))
    x = np.linspace(rv_uniform.ppf(0.01), rv_uniform.ppf(0.99), 100)
    fig, ax = plt.subplots(1, 1)
    ax.plot(x, rv_uniform.pdf(x), 'r-', lw=5, alpha=0.6, label='uniform pdf')
    r = rv_uniform.rvs(size)
    ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])


    ax.legend(loc='best', frameon=False)
    plt.show()

    print("Distribution mean: {0}".format(rv_uniform.stats(moments='m')))
    print("Distribution variance: {0}".format(rv_uniform.stats(moments='v')))
    print("Sample mean: {0}".format(np.mean(r)))
    print("Sample variance: {0}".format(np.var(r)))
uniform_func(1000)
# Out:
# Distribution mean: 3.4641016151377544
# Distribution variance: 15.999999999999998
# Sample mean: 3.2209409898008516
# Sample variance: 15.581095541257568

# %% [markdown]
# #Widać, że powyższy wykres otrzymany przezemnie jest taki sam jak ten z polecenia.
# #Przy parametrach loc=-2*np.sqrt(3), scale=8*np.sqrt(3)

# %% [markdown]
# # Low of large numbers. Central Limit Theorem.
# ## Ex 2.
# a) For N from 2 to 1000 draw N samples from distributions defined in Ex 1. Plot sample variance and mean against the size of the sample.

# %%
def norm_2(size):
    rv_norm = norm(loc = 1, scale = 4)
    r = rv_norm.rvs(size)
    return np.mean(r), np.var(r);

def exp_2(size):
    rv_exp = expon(loc = 0, scale = 4)
    r = rv_exp.rvs(size)
    return np.mean(r), np.var(r);

def chi2_2(size):
    rv_chi2 = chi2(df=8, loc=0, scale=1)
    r = rv_chi2.rvs(size)
    return np.mean(r), np.var(r);

def uniform_2(size):
    rv_uniform = uniform(loc=-2*np.sqrt(3), scale=8*np.sqrt(3))
    r = rv_uniform.rvs(size)
    return np.mean(r), np.var(r);
print("DONE")
# Out:
# DONE

# %%
N = np.array([i for i in range(2,1000)])

mean={}
variance={}

for x,xx in [(norm_2,"Normal"),(exp_2,"Exponential"),(chi2_2,"Chi2"),(uniform_2,"Uniform")]:
    mean[xx], variance[xx] = np.vectorize(x)(N)

print("DONE")
# Out:
# DONE

# %%
plt.figure(figsize=(15, 10))

for i,x in [(1,"Normal"),(2,"Exponential"),(3,"Chi2"),(4,"Uniform")]:
    plt.subplot(2, 2, i)
    plt.title(x)
    plt.plot(N.tolist(),mean[x].tolist())
    plt.xlabel('Sample size')
    plt.ylabel('mean')
plt.show()  

plt.figure(figsize=(15, 10))

for i,x in [(1,"Normal"),(2,"Exponential"),(3,"Chi2"),(4,"Uniform")]:
    plt.subplot(2, 2, i)
    plt.title(x)
    plt.plot(N.tolist(),variance[x].tolist())
    plt.xlabel('Sample size')
    plt.ylabel('variance')
plt.show()

# %% [markdown]
# ## Ex 3.
# For N=1,4,9,16 draw histograms of an average over N samples taken from distributions defined in Ex 1.

# %%
X1,
X4,
X9,
X16={}

DANE=[(norm,"normal",0,1,4),
      (expon,"exponential",0,0,4),
      (chi2,"Chi2",8,0,1),
      (uniform,"uniform",0,-2*np.sqrt(3),8*np.sqrt(3))]

for x,xx,dfx,locx,scalex in DANE:
    if dfx==0:
        X1[xx]=x.rvs(loc = locx, scale =scalex, size=(1,1000))
        X4[xx]=np.sum(x.rvs(loc = locx, scale =scalex, size=(4,1000)),axis=0)/4
        X9[xx]=np.sum(x.rvs(loc = locx, scale =scalex, size=(9,1000)),axis=0)/9
        X16[xx]=np.sum(x.rvs(loc = locx, scale =scalex, size=(16,1000)),axis=0)/16
    else:
        X1[xx]=x.rvs(df=dfx, loc = locx, scale =scalex, size=(1,1000))
        X4[xx]=np.sum(x.rvs(df=dfx, loc = locx, scale =scalex, size=(4,1000)),axis=0)/4
        X9[xx]=np.sum(x.rvs(df=dfx, loc = locx, scale =scalex, size=(9,1000)),axis=0)/9
        X16[xx]=np.sum(x.rvs(df=dfx, loc = locx, scale =scalex, size=(16,1000)),axis=0)/16
            

print("DONE")
# Out:
# DONE

# %%
import matplotlib.patches as mpatches
NAMES=["normal","exponential","Chi2","uniform"]

handle=[]
colorl=['blue', 'orange', 'green', 'red']

i=0
for c in colorl:
    handle.append(mpatches.Patch(color=c, alpha=0.3, label=str((i+1)*(i+1))+" samples"))
    i=i+1
    
for x in NAMES:
    plt.figure(figsize=(14, 5))
    plt.hist(X1[x].flatten(), 25, density=True, alpha=0.3, color=colorl[0])
    plt.hist(X4[x].flatten(), 25, density=True,alpha=0.3, color=colorl[1])
    plt.hist(X9[x].flatten(), 25, density=True,alpha=0.3, color=colorl[2])
    plt.hist(X16[x].flatten(), 25, density=True,alpha=0.3, color=colorl[3])
    plt.title("Averaged "+x+" distribution")
    plt.legend(handles=handle,title="Average over:")
    plt.show()

# %%
#Widać, że moje wykresy są takie same jak te z polecenia.

# %% [markdown]
# # Arbitrary distribution sampling
#
# Sometimes it may happen, that we need to sample from a custom distribution, not implemented in any standard library. There exist a simple algorithm for such sampling, provided that the distribution is bounded (pdf has finite support and maximum).
#
#
# #### Accept-rejection sampling
# Let the distribution be given by the pdf $g(x)$ and defined at interval $[a,b]$. In addition, let $M$ be the supremum of $g(x)$.
#
# 1. Take a sample $t$ from the uniform distribution at the interval $[a,b]$,
# 2. Take a sample $u$ from the uniform distribution at the interval $[0,M]$,
# 3. If $g(t) > u$ we accept $t$ as a sample taken from the original distribution. If not, we go back to 1.
#
# ## Ex 4.
# Implement function accept_rejection_sampling(dist, size = 1) which samples from any bounded distribution on the [0,1] interval.

# %%
import numpy as np
from scipy.stats import norm, expon, chi2, uniform
import matplotlib.pyplot as plt
import pandas as pd

def toy_dist(x):
    C = 1/3 - np.exp(-4)/4 + 1/4
    return (x**2 + np.exp(-4*x)) / C 

x = np.linspace(0,1,1000)


def accept_rejection_sampling(dist, size = 1):
    #here goes your code
    naccept=0
    ymax=np.max(dist)
    samples=[]
    
    while naccept<size:  
        x=np.random.uniform(0,1)  
        y=np.random.uniform(0,ymax)   
        if y<toy_dist(x):  
            samples.append(x)  
            naccept=naccept+1  
    samples=np.array(samples)  
    
    return samples


samples = accept_rejection_sampling(toy_dist(x), size = 10000)

fig, ax = plt.subplots(1, 1)
ax.plot(x, toy_dist(x), 'r-', lw=5, alpha=0.6, label='toy pdf')
ax.hist(samples, density=True, histtype='stepfilled', alpha=0.2, bins = x[::40], label = "sampled")
ax.legend(loc='best', frameon=False)
plt.show()

# %%
#Widać, że otrzymałem to co było wymagane w poleceniu.

# %% [markdown]
# # Probability space matters!
# ## Ex 5
# Sample 2000 points from the unit disk. Do it in following ways:
# 1. Assume uniform distribution of radius (0,1) and argument (0,2$\pi$),
# 2. Assume uniform distribution of x and y coordinate (-1,1). Drop values laying outside of the disk.
# Explain differences. between 1. and 2. Then:
# 3. Modify the solution of point 1. by changing the distribution of the radius in such a way, that we result in 2D distribution from 2.

# %%
import numpy as np
from scipy.stats import norm, expon, chi2, uniform
import matplotlib.pyplot as plt
import pandas as pd

size=2000


print("START")
#a). Version 1
r=np.random.uniform(0,1,size)  
arg=np.random.uniform(0,2*np.pi,size)   

x=r*np.cos(arg)
y=r*np.sin(arg)

fig, ax = plt.subplots(1, 3, figsize=(15,5),constrained_layout=True)


ax[0].scatter(x, y, lw=2, alpha=0.1)
ax[0].set_xlabel("x")
ax[0].set_ylabel("y")
ax[1].hist(arg,  histtype='stepfilled', alpha=0.2, bins = 20, label = "sampled")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("count")
ax[2].hist(r,  histtype='stepfilled', alpha=0.2, bins = 20, label = "sampled")
ax[2].set_xlabel("r")
ax[2].set_ylabel("count")
fig.suptitle('Version 1', fontsize=16, x=-0.01, y=1.1, verticalalignment='top', horizontalalignment='left')


fig1, ax1 = plt.subplots(1, 3, figsize=(15,5),constrained_layout=True)



print("DONE 1")

#b). Version 2


def radius(x,y):
    return (x**2 + y**2) 

def accept_rejection_sampling2(size = 1):
    #here goes your code
    naccept=0
    xksy=[]
    yki=[]
    while naccept<size: 
        xx=np.random.uniform(-1,1)  
        yy=np.random.uniform(-1,1) 
        if radius(xx,yy)<1:  
            xksy.append(xx) 
            yki.append(yy)
            naccept=naccept+1  
    xksy=np.array(xksy)  
    yki=np.array(yki) 
    return xksy, yki

print("DONE 2")
xksy, yki= accept_rejection_sampling2(size = 2000)

ax1[0].scatter(xksy, yki, lw=2, alpha=0.1)
ax1[0].set_xlabel("x")
ax1[0].set_ylabel("y")
ax1[1].hist(xksy,  histtype='stepfilled', alpha=0.2, bins = 20, label = "sampled")
ax1[1].set_xlabel("x")
ax1[1].set_ylabel("count")
ax1[2].hist(yki,  histtype='stepfilled', alpha=0.2, bins = 20, label = "sampled")
ax1[2].set_xlabel("y")
ax1[2].set_ylabel("count")
fig1.suptitle('Version 2', fontsize=16, x=-0.01, y=1.1, verticalalignment='top', horizontalalignment='left')


#c). Version 3

def pdf(r):
    return 2*r 
rl=np.linspace(0,1,1000)

def accept_rejection_sampling3(dist, size = 1):
    #here goes your code
    naccept=0
    rr=[]
    ymax=np.max(dist)
    while naccept<size: 
        r=np.random.uniform(0,1) 
        y=np.random.uniform(0,ymax)
        if y<pdf(r):  
            rr.append(r) 
            naccept=naccept+1      
    return rr


r=accept_rejection_sampling3(pdf(rl),size)  
arg=np.random.uniform(0,2*np.pi,size)   

x2=r*np.cos(arg)
y2=r*np.sin(arg)

fig2, ax2 = plt.subplots(1, 3, figsize=(15,5),constrained_layout=True)

ax2[0].scatter(x2, y2, lw=2, alpha=0.1)
ax2[0].set_xlabel("x")
ax2[0].set_ylabel("y")
ax2[1].hist(arg,  histtype='stepfilled', alpha=0.2, bins = 20, label = "sampled")
ax2[1].set_xlabel("alpha")
ax2[1].set_ylabel("count")
ax2[2].hist(r,  histtype='stepfilled', alpha=0.2, bins = 20, label = "sampled")
ax2[2].set_xlabel("r")
ax2[2].set_ylabel("count")
fig2.suptitle('Version 3', fontsize=16, x=-0.01, y=1.1, verticalalignment='top', horizontalalignment='left')


plt.show()

print("STOP")
# Out:
# START
# DONE 1
# DONE 2
# STOP

# %% [markdown]
# Here goes your explanation

# %% [markdown]
# Version 3 Wyjaśnienie:
#
# W momencie gdy losujemy współrzędne kartezjańskie z jednorodnych rozkładów gęstości od (-1,1)
# otrzymujemy jednorodny rozkłąd punktów. Gęstość punktów nie zmienia się wraz z rosnącą odległością od środka układu współrzędnych.
#
# Aby otrzymać ten sam efekt dla współrzędnych polarnych rozkład gęstości r powinien wynosić pdf(r)=2r.
#
# Wynika to z tego, że aby gęstość punktów na obwodzie okręgu dla promienia r była stała,
# potrzebyjemy liniowo rosnącej gęstości.
#
# Zauważmy, że obwód jest proporcjonalny do x=2r. Zatem pdf(x)=2x <=> pdf(r)=2r.

# %%
#Version3
# Out:
# Version 3

# %% [markdown]
# ## Application: Laplace equation, Dirichlet boundary conditions
#
# #### Monte-Carlo procedure for solving 2D Laplace equation with Dirichlet boundary conditions
# 1. Start in a random position inside the boundaries,
# 2. With an equal probability move up/down/right/left until you hit the boundary,
# 3. After hitting the boundary we take the value $v_{b}$ of the function in the hitting point. We update the values of all points along the just finished random walk using the formula:
# $$ v_{new} = \dfrac{nv_{old} + v_{b}}{n+1}, $$
# where $n$ is a number of random walks which have already passed through this point.
# 4. Finish if the desired precision is achieved. If not, go back to 1.
#
#
# A theory behind the above procedure can be found here:
# https://www.uzh.ch/cmsssl/physik/dam/jcr:d559688c-1e7f-44ca-9fbe-aab0755c0b6e/empp18_MC_Markov.pdf

# %% [markdown]
# ## Ex 6
# Implement the method described above and solve numerically given Dirichlet problem. Plot few intermediate steps.

# %%
print("START")
#here goes your code
S = 100 # Decrease if computations take too long
plane = np.zeros((S,S))
plane_counts = np.zeros((S,S))
plane[0] = np.cos(np.linspace(-1.5,1.5,S)*2*np.pi)
plane[-1] = -np.cos(np.linspace(-1,1,S)*2*np.pi)
plane[:,0] = np.cos(np.linspace(-0.5,0.5,S)*2*np.pi)
plane[:,-1] = -2+np.linspace(-1,1,S)**2


plt.figure(figsize=(20,20))
image=1

#316,913,2616,7491,20553
for liczba in [0,5,38,110,316,913,2616,7491,20553]:


    plt.subplot(3,3,image)
    plt.title(str(liczba)+" walks")
    plt.imshow(plane)
    #im.set_array(planes[0])
    image=image+1
    for j in range(liczba):


        #initial point
        idx=np.random.randint(0,99)  
        idy=np.random.randint(0,99)

    

        x=[]
        y=[]

        x.append(idx)
        y.append(idy)

        # filling the coordinates with random variables 
        while (idx!=0 and idx!=99 and idy!=0 and idy!=99):
            plane_counts[idx][idy]=plane_counts[idx][idy]+1
            val = random.randint(1, 4) 
            if val == 1: 
                idx = idx + 1
                idy = idy
            elif val == 2: 
                idx = idx - 1
                idy = idy 
            elif val == 3: 
                idx = idx 
                idy = idy + 1
            else: 
                idx = idx 
                idy = idy - 1
            x.append(idx)
            y.append(idy)

        for i in range(len(x)):
            plane[x[i]][y[i]]=(plane_counts[x[i]][y[i]]*plane[x[i]][y[i]]+plane[x[-1]][y[-1]])/(plane_counts[x[i]][y[i]]+1)   

        plt.imshow(plane)

 
    
plt.show()
print("DONE")
# Out:
# START
# DONE
